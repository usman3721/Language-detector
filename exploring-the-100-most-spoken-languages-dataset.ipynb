# %% [markdown]
# The purpose of this notebook study is to examine the top 100 languages used globally with respect to native and non native speakers.

# %%
import numpy as np
import pandas as pd
import plotly.express as px
print ("Good to go")
# Out:
# Good to go

# %%
file_pathway = "../input/100-most-spoken-languages-around-the-world/Top 100 Languages.csv"
data = pd.read_csv(file_pathway, decimal= ',')
data.dtypes
# Out:
# Language            object
# Total Speakers       int64
# Native Speakers    float64
# Origin              object
# dtype: object

# %%
data.head(5)
# Out:
#            Language  Total Speakers  Native Speakers         Origin
# 0           English      1132366680      379007140.0  Indo-European
# 1  Mandarin Chinese      1116596640      917868640.0   Sino-Tibetan
# 2             Hindi       615475540      341208640.0  Indo-European
# 3           Spanish       534335730      460093030.0  Indo-European
# 4            French       279821930       77177210.0  Indo-European

# %% [markdown]
# As of now, our Native Speakers column is producing values with ".0" trailing because this column data type is float.
#
# We'll have to change this to integer after missing values (NaNs) are removed.
#
# Additonally languages are indexed 0-99 as opposed to 1-100.
# The following code is used to reflect the necessary change.

# %%
data.index=np.arange(1,len(data)+1)

# %%
data.columns=(["Language","Total_Speakers","Native_Speakers","Origin"])
data.Language=data.Language.astype('category')
data.Origin=data.Origin.astype('category')

# %% [markdown]
# There are 42 different Indo-European languages in the database that account for more than half (55.7%) of all the total speakers among the 100 languages when grouped by language origins.

# %%
data['Origin'].value_counts()
# Out:
# Indo-European    42
# Afro-Asiatic     15
# Niger-Congo      12
# Sino-Tibetan      9
# Austronesian      9
# Turkic            4
# Dravidian         4
# Kra-Dai           2
# Uralic            1
# Koreanic          1
# Japanic           1
# Name: Origin, dtype: int64

# %%
fig = px.pie(data, values='Total_Speakers', names='Origin', title="Percentage Breakdown of Language Groups")
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="e8d27e75-cdd8-405b-8a41-cd1e75def869" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e8d27e75-cdd8-405b-8a41-cd1e75def869")) {                    Plotly.newPlot(                        "e8d27e75-cdd8-405b-8a41-cd1e75def869",                        [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "Origin=%{label}<br>Total_Speakers=%{value}<extra></extra>", "labels": ["Indo-European", "Sino-Tibetan", "Indo-European", "Indo-European", "Indo-European", "Afro-Asiatic", "Indo-European", "Indo-European", "Indo-European", "Austronesian", "Indo-European", "Indo-European", "Japanic", "Niger-Congo", "Indo-European", "Dravidian", "Indo-European", "Sino-Tibetan", "Dravidian", "Turkic", "Koreanic", "Austronesian", "Sino-Tibetan", "Austronesian", "Indo-European", "Afro-Asiatic", "Afro-Asiatic", "Kra-Dai", "Indo-European", "Dravidian", "Indo-European", "Indo-European", "Sino-Tibetan", "Sino-Tibetan", "Sino-Tibetan", "Austronesian", "Sino-Tibetan", "Indo-European", "Niger-Congo", "Indo-European", "Dravidian", "Sino-Tibetan", "Indo-European", "Indo-European", "Afro-Asiatic", "Indo-European", "Austronesian", "Afro-Asiatic", "Afro-Asiatic", "Indo-European", "Niger-Congo", "Niger-Congo", "Afro-Asiatic", "Turkic", "Indo-European", "Afro-Asiatic", "Indo-European", "Indo-European", "Austronesian", "Indo-European", "Afro-Asiatic", "Sino-Tibetan", "Indo-European", "Indo-European", "Indo-European", "Niger-Congo", "Austronesian", "Austronesian", "Indo-European", "Indo-European", "Afro-Asiatic", "Indo-European", "Austronesian", "Afro-Asiatic", "Indo-European", "Kra-Dai", "Indo-European", "Afro-Asiatic", "Niger-Congo", "Indo-European", "Niger-Congo", "Turkic", "Niger-Congo", "Niger-Congo", "Niger-Congo", "Indo-European", "Indo-European", "Indo-European", "Turkic", "Indo-European", "Indo-European", "Uralic", "Niger-Congo", "Indo-European", "Niger-Congo", "Indo-European", "Indo-European", "Afro-Asiatic", "Afro-Asiatic", "Afro-Asiatic"], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": [1132366680, 1116596640, 615475540, 534335730, 279821930, 273989700, 265042480, 258227760, 234168620, 198733600, 170208780, 132176520, 128350830, 98327740, 95312800, 93040340, 92725700, 81501290, 80989130, 79779360, 77264890, 76950770, 73538610, 68277600, 67894920, 64618100, 63428100, 60657660, 60588970, 56463310, 52782160, 52405300, 50462190, 48467490, 46900000, 45000000, 42912350, 40378030, 39844260, 38051547, 37829870, 37300000, 34085000, 33082790, 32608700, 32601140, 32400000, 32387600, 31940300, 30000000, 27779100, 27014190, 25880630, 25164820, 24615591, 24587400, 24528840, 24345750, 23808890, 23069480, 22400000, 22100000, 20850900, 20746400, 20009000, 19183300, 19092180, 17591230, 17534580, 17287880, 16321530, 16300000, 15942480, 15655900, 15329040, 15000000, 14605670, 14524500, 14485000, 14359000, 14102320, 13813750, 13731000, 13664710, 13524520, 13386850, 13170460, 13000000, 12934060, 12804900, 12800000, 12574280, 12486000, 12131225, 12120250, 12000000, 11800000, 11601100, 11571600, 11350000]}],                        {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth ...

# %%
fig=px.bar(data, x="Language", y="Total_Speakers", color="Origin", title="Total Speakers Grouped by Origin",
          width=1500, height=800)
fig.update_yaxes(ticks="outside", tickwidth=2, tickcolor='crimson', ticklen=10)
fig.update_layout(
    title="Total Speakers of Languages Grouped By Origin",
    title_font_size=20,
    yaxis_title="Total Speakers",
    legend_title="Language Origin",
    font=dict(
        family="Courier New, monospace",
        color="Black"))
fig.show()
# Out:
# <div>                            <div id="33b208db-a0c0-4c4b-a1c9-1207bca8667b" class="plotly-graph-div" style="height:800px; width:1500px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("33b208db-a0c0-4c4b-a1c9-1207bca8667b")) {                    Plotly.newPlot(                        "33b208db-a0c0-4c4b-a1c9-1207bca8667b",                        [{"alignmentgroup": "True", "hovertemplate": "Origin=Indo-European<br>Language=%{x}<br>Total_Speakers=%{y}<extra></extra>", "legendgroup": "Indo-European", "marker": {"color": "#636efa"}, "name": "Indo-European", "offsetgroup": "Indo-European", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["English", "Hindi", "Spanish", "French", "Bengali", "Russian", "Portuguese", "Urdu", "Standard German", "Marathi", "Western Punjabi", "Italian", "Gujarati", "Iranian Persian", "Bhojpuri", "Polish", "Odia", "Maithili", "Ukrainian", "Eastern Punjabi", "Nigerian Pidgin", "Sindhi", "Nepali", "Romanian", "Dutch", "Northern Pashto", "Magahi", "Saraiki", "Afrikaans", "Sinhala", "Chhattisgarhi", "Assamese", "Northern Kurdish", "Bavarian", "Czech", "Greek", "Chittagonian", "Swedish", "Deccan", "Sadri", "Cameroonian Pidgin", "Sylheti"], "xaxis": "x", "y": [1132366680, 615475540, 534335730, 279821930, 265042480, 258227760, 234168620, 170208780, 132176520, 95312800, 92725700, 67894920, 60588970, 52782160, 52405300, 40378030, 38051547, 34085000, 33082790, 32601140, 30000000, 24615591, 24528840, 24345750, 23069480, 20850900, 20746400, 20009000, 17534580, 17287880, 16300000, 15329040, 14605670, 14359000, 13386850, 13170460, 13000000, 12804900, 12800000, 12131225, 12000000, 11800000], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Origin=Sino-Tibetan<br>Language=%{x}<br>Total_Speakers=%{y}<extra></extra>", "legendgroup": "Sino-Tibetan", "marker": {"color": "#EF553B"}, "name": "Sino-Tibetan", "offsetgroup": "Sino-Tibetan", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Mandarin Chinese", "Wu Chinese", "Yue Chinese", "Southern Min Chinese", "Hakka Chinese", "Jinyu Chinese", "Burmese", "Xiang Chinese", "Gan Chinese"], "xaxis": "x", "y": [1116596640, 81501290, 73538610, 50462190, 48467490, 46900000, 42912350, 37300000, 22100000], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Origin=Afro-Asiatic<br>Language=%{x}<br>Total_Speakers=%{y}<extra></extra>", "legendgroup": "Afro-Asiatic", "marker": {"color": "#00cc96"}, "name": "Afro-Asiatic", "offsetgroup": "Afro-Asiatic", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Standard Arabic", "Egyptian Spoken Arabic", "Hausa", "Moroccan Spoken Arabic", "Algerian Spoken Arabic", "Sundanese Spoken Arabic", "Amharic", "North Levantine Spoken Arabic", "Sa'idi Spoken Arabic", "Somali", "Mesopotamian Spoken Arabic", "Hijazi Spoken Arabic", "South Levantine Spoken Arabic", "Tunisian Spoken Arabic", "Sanaani Spoken Arabic"], "xaxis": "x", "y": [273989700, 64618100, 63428100, 32608700, 32387600, 31940300, 25880630, 24587400, 22400000, 16321530, 15655900, 14524500, 11601100, 11571600, 11350000], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Origin=Austronesian<br>Language=%{x}<br>Total_Speakers=%{y}<extra></extra>", "legendgroup": "Austronesian", "marker": {"color": "#ab63fa"}, "name": "Austronesian", "offsetgroup": "Austronesian", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Indonesian", "Vietnamese", "Javanese", "Filipino", "Sunda", "Tagalog", "Malay", "Khmer", "Cebuano"], "xaxis": "x", "y": [198733600, 76950770, 68277600, 45000000, 32400000, 23808890, 19092180, 17591230, 15942480], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Origin=Japanic<br>Language=%{x}<br>Total_Speakers=%{y}<extra></extra>", "l ...

# %% [markdown]
# Before looking into the data further, missing values will be dealt with.

# %%
null_columns=data.columns[data.isnull().any()]
data[null_columns].isnull().sum()
# Out:
# Native_Speakers    4
# dtype: int64

# %%
is_NaN=data.isnull()
NaN_rows=is_NaN.any(axis=1)
rows_with_NaN=data[NaN_rows]
print(rows_with_NaN)
# Out:
#               Language  Total_Speakers  Native_Speakers         Origin
# 6      Standard Arabic       273989700              NaN   Afro-Asiatic
# 36            Filipino        45000000              NaN   Austronesian
# 50     Nigerian Pidgin        30000000              NaN  Indo-European
# 96  Cameroonian Pidgin        12000000              NaN  Indo-European

# %% [markdown]
# There are four languages in the database that have missing values for the number of Native Speakers.
#
# For these languages only the number of total speakers is provided.
# They are:
# - Standard Arabic (273.9 million, Afro-Asiatic)
# - Filipino (45 million, Austronesian)
# - Nigerian Pidgin (30 million, Indo-European)
# - Cameroonian Pidgin (12 million, Indo-European).
#
# In terms of Total Speakers, these are the 6th, 36th, 50th and 96th most spoken language in the world respectively.
#
# We will delete these because when comparing Native Speakers they do not add significance.

# %%
data.drop([6,36,50,96], inplace=True)

# %% [markdown]
# In addition to converting the Native Speakers column into an integer data type following the elimination of NaNs, we will create 2 columns, Insularity and Non Native. Insularity is expressed as a percentage of the number of Native Speakers divided by Total Speakers for a given language. The higher the outcome, the more insular the language is as speakers are mostly native. Conversely, the lower the number, the more the given language is being spread amongst non native speakers as second or third languages acquired etc.
#
# Non Native is simply calculated as the number of Total Speakers subtracted by the number of Native Speakers. This column tells us the number of speakers who have learned said language perhaps for work, travel, translation, pleasure or have picked it up along the way.
#
# We will round the Insularity to 4 decimal places rather than the standard 2. The reason being, a minor number of Non Native speakers will falsely round to 100% insularity. Here is a demonstration of this inaccuracy:

# %%
data.Native_Speakers=data.Native_Speakers.astype('int')
data['Non_Native']=data['Total_Speakers'] - data['Native_Speakers']
data.Non_Native=data.Non_Native.astype('int')
data['Insularity']=data['Native_Speakers']/data['Total_Speakers']*100
data['Insularity']=data['Insularity'].round(decimals=2)
total_insularity=data.loc[data['Insularity'] == 100]
total_insularity.head(10)
# Out:
#                   Language  Total_Speakers  Native_Speakers         Origin  \
# 17         Western Punjabi        92725700         92725700  Indo-European
# 21                  Korean        77264890         77264890       Koreanic
# 24                Javanese        68277600         68277600   Austronesian
# 26  Egyptian Spoken Arabic        64618100         64618100   Afro-Asiatic
# 31         Iranian Persian        52782160         52782160  Indo-European
# 34           Hakka Chinese        48467490         48467490   Sino-Tibetan
# 35           Jinyu Chinese        46900000         46900000   Sino-Tibetan
# 42           Xiang Chinese        37300000         37300000   Sino-Tibetan
# 46         Eastern Punjabi        32601140         32600670  Indo-European
# 47                   Sunda        32400000         32400000   Austronesian
#
#     Non_Native  Insularity
# 17           0       100.0
# 21           0       100.0
# 24           0       100.0
# 26           0       100.0
# 31           0       100.0
# 34           0       100.0
# 35           0       100.0
# 42           0       100.0
# 46         470       100.0
# 47           0       100.0

# %% [markdown]
# As you can see the Eastern Punjabi language in the database records 470 Non Native speakers, however Insularity is falsely rounded to 100%. To reflect a more accurate reading of Insularity, 4 decimals places will be required.

# %%
data['Insularity']=data['Native_Speakers']/data['Total_Speakers']*100
data['Insularity']=data['Insularity'].round(decimals=4)
total_insularity=data.loc[data['Insularity'] == 100]
len(total_insularity)
# Out:
# 36

# %%
#Languages with 100% insularity based on data provided
total_insularity
# Out:
#                           Language  Total_Speakers  Native_Speakers  \
# 17                 Western Punjabi        92725700         92725700
# 21                          Korean        77264890         77264890
# 24                        Javanese        68277600         68277600
# 26          Egyptian Spoken Arabic        64618100         64618100
# 31                 Iranian Persian        52782160         52782160
# 34                   Hakka Chinese        48467490         48467490
# 35                   Jinyu Chinese        46900000         46900000
# 42                   Xiang Chinese        37300000         37300000
# 47                           Sunda        32400000         32400000
# 49         Sundanese Spoken Arabic        31940300         31940300
# 52                            Igbo        27014190         27014190
# 54                  Northern Uzbek        25164820         25164820
# 56   North Levantine Spoken Arabic        24587400         24587400
# 58                        Romanian        24345750         24345750
# 60                           Dutch        23069480         23069480
# 61            Sa'idi Spoken Arabic        22400000         22400000
# 62                     Gan Chinese        22100000         22100000
# 63                 Northern Pashto        20850900         20850900
# 65                         Saraiki        20009000         20009000
# 72                   Chhattisgarhi        16300000         16300000
# 73                         Cebuano        15942480         15942480
# 74      Mesopotamian Spoken Arabic        15655900         15655900
# 76               Northeastern Thai        15000000         15000000
# 77                Northern Kurdish        14605670         14605670
# 78            Hijazi Spoken Arabic        14524500         14524500
# 79               Nigerian Fulfulde        14485000         14485000
# 80                        Bavarian        14359000         14359000
# 82               South Azerbaijani        13813750         13813750
# 88                    Chittagonian        13000000         13000000
# 89                          Kazakh        12934060         12934060
# 91                          Deccan        12800000         12800000
# 92                       Hungarian        12574280         12574280
# 95                     Kinyarwanda        12120250         12120250
# 98   South Levantine Spoken Arabic        11601100         11601100
# 99          Tunisian Spoken Arabic        11571600         11571600
# 100          Sanaani Spoken Arabic        11350000         11350000
#
#             Origin  Non_Native  Insularity
# 17   Indo-European           0       100.0
# 21        Koreanic           0       100.0
# 24    Austronesian           0       100.0
# 26    Afro-Asiatic           0       100.0
# 31   Indo-European           0       100.0
# 34    Sino-Tibetan           0       100.0
# 35    Sino-Tibetan           0       100.0
# 42    Sino-Tibetan           0       100.0
# 47    Austronesian           0       100.0
# 49    Afro-Asiatic           0       100.0
# 52     Niger-Congo           0       100.0
# 54          Turkic           0       100.0
# 56    Afro-Asiatic           0       100.0
# 58   Indo-European           0       100.0
# 60   Indo-European           0       100.0
# 61    Afro-Asiatic           0       100.0
# 62    Sino-Tibetan           0       100.0
# 63   Indo-European           0       100.0
# 65   Indo-European           0       100.0
# 72   Indo-European           0       100.0
# 73    Austronesian           0       100.0
# 74    Afro-Asiatic           0       100.0
# 76         Kra-Dai           0       100.0
# 77   Indo-European           0       100.0
# 78    Afro-Asiatic           0       100.0
# 79     Niger-Congo           0       100.0
# 80   Indo-European           0       100.0
# 82          Turkic           0       100.0
# 88   Indo-European           0       100.0
# 89          Turkic           0       100.0
# 91   Indo-European           0       100.0
# 92          Uralic           0       100.0
# 95     Niger-Congo           0       100.0
# 98    Afro-Asiatic           0       100.0
# 99    Afro-Asiatic           0       100.0
# 100   Afro-Asiatic           0       100.0

# %%
fig = px.bar(total_insularity, x="Language", y="Total_Speakers", color='Origin', width=1000, height=700,title="Total Insularity Languages by Origin")
fig.update_xaxes(tickangle=90, tickfont=dict(family='Courier New', color='black', size=14))
fig.update_yaxes(ticks="outside", tickwidth=2, tickcolor='crimson', ticklen=10)
fig.update_layout(
    title="Completely Insular Languages Grouped By Origin",
    title_font_size=20,
    yaxis_title="Total Speakers",
    legend_title="Language Origin",
    font=dict(
        family="Courier New, monospace",
        color="Black"))
fig.show()
# Out:
# <div>                            <div id="a1960713-7463-4a59-8eae-55b6d51dd229" class="plotly-graph-div" style="height:700px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a1960713-7463-4a59-8eae-55b6d51dd229")) {                    Plotly.newPlot(                        "a1960713-7463-4a59-8eae-55b6d51dd229",                        [{"alignmentgroup": "True", "hovertemplate": "Origin=Indo-European<br>Language=%{x}<br>Total_Speakers=%{y}<extra></extra>", "legendgroup": "Indo-European", "marker": {"color": "#636efa"}, "name": "Indo-European", "offsetgroup": "Indo-European", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Western Punjabi", "Iranian Persian", "Romanian", "Dutch", "Northern Pashto", "Saraiki", "Chhattisgarhi", "Northern Kurdish", "Bavarian", "Chittagonian", "Deccan"], "xaxis": "x", "y": [92725700, 52782160, 24345750, 23069480, 20850900, 20009000, 16300000, 14605670, 14359000, 13000000, 12800000], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Origin=Koreanic<br>Language=%{x}<br>Total_Speakers=%{y}<extra></extra>", "legendgroup": "Koreanic", "marker": {"color": "#EF553B"}, "name": "Koreanic", "offsetgroup": "Koreanic", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Korean"], "xaxis": "x", "y": [77264890], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Origin=Austronesian<br>Language=%{x}<br>Total_Speakers=%{y}<extra></extra>", "legendgroup": "Austronesian", "marker": {"color": "#00cc96"}, "name": "Austronesian", "offsetgroup": "Austronesian", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Javanese", "Sunda", "Cebuano"], "xaxis": "x", "y": [68277600, 32400000, 15942480], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Origin=Afro-Asiatic<br>Language=%{x}<br>Total_Speakers=%{y}<extra></extra>", "legendgroup": "Afro-Asiatic", "marker": {"color": "#ab63fa"}, "name": "Afro-Asiatic", "offsetgroup": "Afro-Asiatic", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Egyptian Spoken Arabic", "Sundanese Spoken Arabic", "North Levantine Spoken Arabic", "Sa'idi Spoken Arabic", "Mesopotamian Spoken Arabic", "Hijazi Spoken Arabic", "South Levantine Spoken Arabic", "Tunisian Spoken Arabic", "Sanaani Spoken Arabic"], "xaxis": "x", "y": [64618100, 31940300, 24587400, 22400000, 15655900, 14524500, 11601100, 11571600, 11350000], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Origin=Sino-Tibetan<br>Language=%{x}<br>Total_Speakers=%{y}<extra></extra>", "legendgroup": "Sino-Tibetan", "marker": {"color": "#FFA15A"}, "name": "Sino-Tibetan", "offsetgroup": "Sino-Tibetan", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Hakka Chinese", "Jinyu Chinese", "Xiang Chinese", "Gan Chinese"], "xaxis": "x", "y": [48467490, 46900000, 37300000, 22100000], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Origin=Niger-Congo<br>Language=%{x}<br>Total_Speakers=%{y}<extra></extra>", "legendgroup": "Niger-Congo", "marker": {"color": "#19d3f3"}, "name": "Niger-Congo", "offsetgroup": "Niger-Congo", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Igbo", "Nigerian Fulfulde", "Kinyarwanda"], "xaxis": "x", "y": [27014190, 14485000, 12120250], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Origin=Turkic<br>Language=%{x}<br>Total_Speakers=%{y}<extra></extra>", "legendgroup": "Turkic", "marker": {"color": "#FF6692"}, "name": "Turkic", "offsetgroup": "Turkic", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Northern Uzbek", "South Azerbaijani", "Kazakh"], "xaxis": "x", "y": [25164820, 13813750, 12934060], "yaxis": "y"}, {"alignmentgroup": " ...

# %% [markdown]
# There are a total of 36 languages in the database in which Total Speakers is equal to the number of Native Speakers, indicating that there are zero Non Native Speakers. Rather than labelling these languages as unforgivingly insular, a more realistic picture of this may simply be a result of incomplete data. For instance, the Korean language is spoken by several non Koreans which can be observed whenever spending time there.
#
# On another elaborative note, the language belongs to origin group of Koreanic. Interestingly enough however, both the Korean and the Tamil languages (Dravidian origin) make use of the same word or sound we can say for the words meaning "mother" and "father". This could be a great discussion to be had between Jonathan D. Ripley of the Department of South Asian Studies at Harvard University and researcher Jung Nam Kim that may lead to Chola and Song dynasty unravellings. Of course such talks can only safely occur outside of Ontario Canada.
#
# Nonetheless for the purpose of this notebook, we will exclude all languages in the database without non native speakers as they lend no further comparative value.
#
# After dropping these 36 languages in which Non Native information is absent in addition to the 4 languages dropped previously for missing data, we will be left with 60 of the inital 100 in the database to examine.

# %%
data.drop(data.loc[data['Non_Native']==0].index, inplace=True)
len(data)
# Out:
# 60

# %%
most_total=data.sort_values(by='Total_Speakers', ascending=False)
ab=most_total.head(10)
ab
# Out:
#             Language  Total_Speakers  Native_Speakers         Origin  \
# 1            English      1132366680        379007140  Indo-European
# 2   Mandarin Chinese      1116596640        917868640   Sino-Tibetan
# 3              Hindi       615475540        341208640  Indo-European
# 4            Spanish       534335730        460093030  Indo-European
# 5             French       279821930         77177210  Indo-European
# 7            Bengali       265042480        228289600  Indo-European
# 8            Russian       258227760        153746530  Indo-European
# 9         Portuguese       234168620        220762620  Indo-European
# 10        Indonesian       198733600         43364600   Austronesian
# 11              Urdu       170208780         68622980  Indo-European
#
#     Non_Native  Insularity
# 1    753359540     33.4704
# 2    198728000     82.2023
# 3    274266900     55.4382
# 4     74242700     86.1056
# 5    202644720     27.5808
# 7     36752880     86.1332
# 8    104481230     59.5391
# 9     13406000     94.2751
# 10   155369000     21.8205
# 11   101585800     40.3169

# %% [markdown]
# When taking a further look into the Top 10 most spoken languages in terms of Total Speakers by way of Native and Non Native Speakers, a visualization articulates the workings of Insularity on the population on a language's total number of speakers.
# In the top 10 most spoken group, fours languages that stand out in terms of reach outside of Native Speakers are:
#
# - English (33.47% insularity; most spoken language)
# - French (27.58% insularity; 5th most spoken language)
# - Indonesian (21.82% insularity; 10th most spoken language)
# - Urdu (40.32% insularity; 11th most spoken language)
#
# These low levels of insularity amongst these popular languages all indicate that more than 50% (for English two-thirds) of all speakers are Non Natives!

# %%
fig = px.bar(ab, x="Language", y=["Native_Speakers","Non_Native"], title="Breakdown of 10 Most Spoken Languages")
fig.show()
# Out:
# <div>                            <div id="bc963ced-bcde-4100-8408-fc53aa4d914e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bc963ced-bcde-4100-8408-fc53aa4d914e")) {                    Plotly.newPlot(                        "bc963ced-bcde-4100-8408-fc53aa4d914e",                        [{"alignmentgroup": "True", "hovertemplate": "variable=Native_Speakers<br>Language=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Native_Speakers", "marker": {"color": "#636efa"}, "name": "Native_Speakers", "offsetgroup": "Native_Speakers", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["English", "Mandarin Chinese", "Hindi", "Spanish", "French", "Bengali", "Russian", "Portuguese", "Indonesian", "Urdu"], "xaxis": "x", "y": [379007140, 917868640, 341208640, 460093030, 77177210, 228289600, 153746530, 220762620, 43364600, 68622980], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "variable=Non_Native<br>Language=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Non_Native", "marker": {"color": "#EF553B"}, "name": "Non_Native", "offsetgroup": "Non_Native", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["English", "Mandarin Chinese", "Hindi", "Spanish", "French", "Bengali", "Russian", "Portuguese", "Indonesian", "Urdu"], "xaxis": "x", "y": [753359540, 198728000, 274266900, 74242700, 202644720, 36752880, 104481230, 13406000, 155369000, 101585800], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "variable"}, "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201 ...

# %% [markdown]
# There are a total of 15 languages in the database in which the majority (50%+) of speakers are Non Natives.
# More simply, these languages have more Non Native speakers today than Native speakers.
# Namely from least insular, they are as follows:
#
# - Swahili (16.3% - insert 2pac lyric here)
# - Jula (17.68%)
# - Indonesian (21.82%)
# - French (27.58)
# - Bamanankan (29.09%)
# - English (33.47%)
# - Northern Sotho (33.73%)
# - Thai (34.56%)
# - Urdu (40.32%)
# - Afrikaans (41.26%)
# - Southern Sotho (41.59%)
# - Sadri (42.30%)
# - Setswana (42.55%)
# - Xhosa (42.66%)
# - Zula (43.48%)

# %%
least_insular=data.loc[data['Insularity'] < 50]
least_insular.sort_values('Insularity')
# Out:
#           Language  Total_Speakers  Native_Speakers         Origin  \
# 14         Swahili        98327740         16027740    Niger-Congo
# 93            Jula        12486000          2208000    Niger-Congo
# 10      Indonesian       198733600         43364600   Austronesian
# 5           French       279821930         77177210  Indo-European
# 81      Bamanankan        14102320          4102320    Niger-Congo
# 1          English      1132366680        379007140  Indo-European
# 83  Northern Sotho        13731000          4631000    Niger-Congo
# 28            Thai        60657660         20657660        Kra-Dai
# 11            Urdu       170208780         68622980  Indo-European
# 69       Afrikaans        17534580          7234580  Indo-European
# 85   Souther Sotho        13524520          5624520    Niger-Congo
# 94           Sadri        12131225          5131180  Indo-European
# 84        Setswana        13664710          5814710    Niger-Congo
# 66           Xhosa        19183300          8183300    Niger-Congo
# 51            Zulu        27779100         12079100    Niger-Congo
#
#     Non_Native  Insularity
# 14    82300000     16.3003
# 93    10278000     17.6838
# 10   155369000     21.8205
# 5    202644720     27.5808
# 81    10000000     29.0897
# 1    753359540     33.4704
# 83     9100000     33.7266
# 28    40000000     34.0561
# 11   101585800     40.3169
# 69    10300000     41.2589
# 85     7900000     41.5876
# 94     7000045     42.2973
# 84     7850000     42.5528
# 66    11000000     42.6585
# 51    15700000     43.4827

# %%
fig = px.sunburst(data, path=['Origin','Language'], values='Total_Speakers',
                  color='Non_Native', color_continuous_scale='RdBu', title="Total and Non Native Speakers")
fig.show()
# Out:
# <div>                            <div id="129941a3-7aee-4e09-8a86-3862f816c150" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("129941a3-7aee-4e09-8a86-3862f816c150")) {                    Plotly.newPlot(                        "129941a3-7aee-4e09-8a86-3862f816c150",                        [{"branchvalues": "total", "customdata": [[null], [null], [null], [10300000.0], [null], [null], [null], [null], [null], [null], [null], [3000000.0], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [4000000.0], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [250.0], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [10000000.0], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [36752880.0], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [160000.0], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [10000000.0], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [2682000.0], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [470.0], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [753359540.0], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [202644720.0], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [58500.0], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [4180000.0], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [19500000.0], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [274266900.0], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [155369000.0], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [3050100.0], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [121500.0], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [null], [10278000.0], [null], [null], [null], [null], [null], [12900000.0], [null], [null], [null], [null], [null],  ...

# %%
fig = px.scatter(data, x="Total_Speakers", y="Native_Speakers", size="Non_Native", color="Origin", 
                 title="With Bubble Size as Non Native Speakers - Total Speakers vs. Native Speakers",
           hover_name="Language", log_x=True, log_y=True,size_max=75,width=900, height=600)
fig.update_layout(showlegend=True,
    xaxis={'title':'Total Number of Speakers',},
    yaxis={'title':'Total Number of Native Speakers'})
fig.show()
# Out:
# <div>                            <div id="e4b29c91-1067-47a1-93a5-204071449757" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e4b29c91-1067-47a1-93a5-204071449757")) {                    Plotly.newPlot(                        "e4b29c91-1067-47a1-93a5-204071449757",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>Origin=Indo-European<br>Total_Speakers=%{x}<br>Native_Speakers=%{y}<br>Non_Native=%{marker.size}<extra></extra>", "hovertext": ["English", "Hindi", "Spanish", "French", "Bengali", "Russian", "Portuguese", "Urdu", "Standard German", "Marathi", "Italian", "Gujarati", "Bhojpuri", "Polish", "Odia", "Maithili", "Ukrainian", "Eastern Punjabi", "Sindhi", "Nepali", "Magahi", "Afrikaans", "Sinhala", "Assamese", "Czech", "Greek", "Swedish", "Sadri", "Sylheti"], "legendgroup": "Indo-European", "marker": {"color": "#636efa", "size": [753359540, 274266900, 74242700, 202644720, 36752880, 104481230, 13406000, 101585800, 56086000, 12200000, 3050100, 4180000, 160000, 665000, 3590027, 195000, 5800000, 470, 41, 8680000, 10800, 10300000, 2000000, 250, 2682000, 58500, 3150000, 7000045, 1500000], "sizemode": "area", "sizeref": 133930.5848888889, "symbol": "circle"}, "mode": "markers", "name": "Indo-European", "orientation": "v", "showlegend": true, "type": "scatter", "x": [1132366680, 615475540, 534335730, 279821930, 265042480, 258227760, 234168620, 170208780, 132176520, 95312800, 67894920, 60588970, 52405300, 40378030, 38051547, 34085000, 33082790, 32601140, 24615591, 24528840, 20746400, 17534580, 17287880, 15329040, 13386850, 13170460, 12804900, 12131225, 11800000], "xaxis": "x", "y": [379007140, 341208640, 460093030, 77177210, 228289600, 153746530, 220762620, 68622980, 76090520, 83112800, 64844820, 56408970, 52245300, 39713030, 34461520, 33890000, 27282790, 32600670, 24615550, 15848840, 20735600, 7234580, 15287880, 15328790, 10704850, 13111960, 9654900, 5131180, 10300000], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Origin=Sino-Tibetan<br>Total_Speakers=%{x}<br>Native_Speakers=%{y}<br>Non_Native=%{marker.size}<extra></extra>", "hovertext": ["Mandarin Chinese", "Wu Chinese", "Yue Chinese", "Southern Min Chinese", "Burmese"], "legendgroup": "Sino-Tibetan", "marker": {"color": "#EF553B", "size": [198728000, 63400, 402000, 387000, 10000000], "sizemode": "area", "sizeref": 133930.5848888889, "symbol": "circle"}, "mode": "markers", "name": "Sino-Tibetan", "orientation": "v", "showlegend": true, "type": "scatter", "x": [1116596640, 81501290, 73538610, 50462190, 42912350], "xaxis": "x", "y": [917868640, 81437890, 73136610, 50075190, 32912350], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Origin=Austronesian<br>Total_Speakers=%{x}<br>Native_Speakers=%{y}<br>Non_Native=%{marker.size}<extra></extra>", "hovertext": ["Indonesian", "Vietnamese", "Tagalog", "Malay", "Khmer"], "legendgroup": "Austronesian", "marker": {"color": "#00cc96", "size": [155369000, 1000000, 162000, 3000000, 1000000], "sizemode": "area", "sizeref": 133930.5848888889, "symbol": "circle"}, "mode": "markers", "name": "Austronesian", "orientation": "v", "showlegend": true, "type": "scatter", "x": [198733600, 76950770, 23808890, 19092180, 17591230], "xaxis": "x", "y": [43364600, 75950770, 23646890, 16092180, 16591230], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Origin=Japanic<br>Total_Speakers=%{x}<br>Native_Speakers=%{y}<br>Non_Native=%{marker.size}<extra></extra>", "hovertext": ["Japanese"], "legendgroup": "Japanic", "marker": {"color": "#ab63fa", "size": [121500], "sizemode": "area", "sizeref": 133930.5848888889, "symbol": "circle"}, "mode": "markers", "name": "Japanic", "orientation": "v", "showlegend": true, "type": "scatter", "x": [128350830], "xaxis": "x", "y": [12822 ...

# %%
most_insular=data.loc[data['Insularity']>85]
len(most_insular)
# Out:
# 31

# %% [markdown]
# On the flip side, by arbitrary methodology if we select greater than 85% to signify that a language is insular, there are 31, or just over half of our reduced from 100 to 60 languages in the database that qualify in being insular.
#
# Seeing Spanish, Portuguese, Italian, Polish and Japanese as insular is particulary surprising given the use of these languages in Rosetta Stone products.
# Nonetheless, examining the Total Number of Speakers which is commonly done, does not quite reveal the true workings of language reach.

# %%
most_insular.sort_values('Insularity')
# Out:
#                   Language  Total_Speakers  Native_Speakers         Origin  \
# 4                  Spanish       534335730        460093030  Indo-European
# 7                  Bengali       265042480        228289600  Indo-European
# 15                 Marathi        95312800         83112800  Indo-European
# 97                 Sylheti        11800000         10300000  Indo-European
# 16                  Telugu        93040340         82040340      Dravidian
# 70                 Sinhala        17287880         15287880  Indo-European
# 40                    Odia        38051547         34461520  Indo-European
# 48  Algerian Spoken Arabic        32387600         29387600   Afro-Asiatic
# 19                   Tamil        80989130         75039130      Dravidian
# 29                Gujarati        60588970         56408970  Indo-European
# 9               Portuguese       234168620        220762620  Indo-European
# 68                   Khmer        17591230         16591230   Austronesian
# 39                  Yoruba        39844260         37844260    Niger-Congo
# 25                 Italian        67894920         64844820  Indo-European
# 41              Malayalam         37829870         37134870      Dravidian
# 38                  Polish        40378030         39713030  Indo-European
# 22              Vietnamese        76950770         75950770   Austronesian
# 33    Southern Min Chinese        50462190         50075190   Sino-Tibetan
# 59                 Tagalog        23808890         23646890   Austronesian
# 71                  Somali        16321530         16225930   Afro-Asiatic
# 43                Maithili        34085000         33890000  Indo-European
# 23             Yue Chinese        73538610         73136610   Sino-Tibetan
# 20                 Turkish        79779360         79399060         Turkic
# 87                   Greek        13170460         13111960  Indo-European
# 32                Bhojpuri        52405300         52245300  Indo-European
# 13                Japanese       128350830        128229330        Japanic
# 18              Wu Chinese        81501290         81437890   Sino-Tibetan
# 64                  Magahi        20746400         20735600  Indo-European
# 75                Assamese        15329040         15328790  Indo-European
# 46         Eastern Punjabi        32601140         32600670  Indo-European
# 55                  Sindhi        24615591         24615550  Indo-European
#
#     Non_Native  Insularity
# 4     74242700     86.1056
# 7     36752880     86.1332
# 15    12200000     87.2000
# 97     1500000     87.2881
# 16    11000000     88.1772
# 70     2000000     88.4312
# 40     3590027     90.5654
# 48     3000000     90.7372
# 19     5950000     92.6533
# 29     4180000     93.1011
# 9     13406000     94.2751
# 68     1000000     94.3153
# 39     2000000     94.9805
# 25     3050100     95.5076
# 41      695000     98.1628
# 38      665000     98.3531
# 22     1000000     98.7005
# 33      387000     99.2331
# 59      162000     99.3196
# 71       95600     99.4143
# 43      195000     99.4279
# 23      402000     99.4533
# 20      380300     99.5233
# 87       58500     99.5558
# 32      160000     99.6947
# 13      121500     99.9053
# 18       63400     99.9222
# 64       10800     99.9479
# 75         250     99.9984
# 46         470     99.9986
# 55          41     99.9998
